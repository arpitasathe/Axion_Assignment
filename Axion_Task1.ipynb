# %%
import pandas as pd
from rapidfuzz import process, fuzz
import re


file_path = '/content/drive/MyDrive/Colab Notebooks/Axion_Task2/Task 1.xlsx'
excel_data = pd.ExcelFile(file_path)


task_data = excel_data.parse('Task')
taxonomy_data = excel_data.parse('Taxonomy')


def clean_text(text):

    if pd.isna(text):
        return ''
    text = re.sub(r'[^\w\s]', '', str(text))
    text = re.sub(r'\s+', ' ', text)
    return text.strip().lower()


taxonomy_columns = ['Root Cause', 'Symptom Condition ', 'Symptom Component', 'Fix Condition', 'Fix Component']
taxonomy_cleaned = {col: taxonomy_data[col].dropna().apply(clean_text).tolist() for col in taxonomy_columns}


task_data['Complaint'] = task_data['Complaint'].apply(clean_text)
task_data['Cause'] = task_data['Cause'].apply(clean_text)
task_data['Correction'] = task_data['Correction'].apply(clean_text)



for col in ['Root Cause', 'Symptom Condition 1', 'Symptom Component 1', 'Symptom Condition 2', 'Symptom Component 2',
            'Symptom Condition 3', 'Symptom Component 3', 'Fix Condition 1', 'Fix Component 1', 'Fix Condition 2',
            'Fix Component 2', 'Fix Condition 3', 'Fix Component 3']:
    if col not in task_data.columns:
        task_data[col] = ''


def fuzzy_match(text, options, score_cutoff=80):

    matches = process.extract(text, options, scorer=fuzz.partial_ratio, score_cutoff=score_cutoff)
    return [m[0] for m in matches] if matches else []


def tag_data(row):
    complaint = row['Complaint']
    cause = row['Cause']
    correction = row['Correction']


    root_cause = fuzzy_match(complaint, taxonomy_cleaned['Root Cause']) + fuzzy_match(cause, taxonomy_cleaned['Root Cause'])
    symptom_conditions = fuzzy_match(complaint, taxonomy_cleaned['Symptom Condition ']) + fuzzy_match(cause, taxonomy_cleaned['Symptom Condition '])
    symptom_components = fuzzy_match(complaint, taxonomy_cleaned['Symptom Component']) + fuzzy_match(cause, taxonomy_cleaned['Symptom Component'])
    fix_conditions = fuzzy_match(correction, taxonomy_cleaned['Fix Condition'])
    fix_components = fuzzy_match(correction, taxonomy_cleaned['Fix Component'])


    row['Root Cause'] = root_cause[0] if root_cause else ''
    row['Symptom Condition 1'] = symptom_conditions[0] if len(symptom_conditions) > 0 else ''
    row['Symptom Condition 2'] = symptom_conditions[1] if len(symptom_conditions) > 1 else ''
    row['Symptom Condition 3'] = symptom_conditions[2] if len(symptom_conditions) > 2 else ''
    row['Symptom Component 1'] = symptom_components[0] if len(symptom_components) > 0 else ''
    row['Symptom Component 2'] = symptom_components[1] if len(symptom_components) > 1 else ''
    row['Symptom Component 3'] = symptom_components[2] if len(symptom_components) > 2 else ''
    row['Fix Condition 1'] = fix_conditions[0] if len(fix_conditions) > 0 else ''
    row['Fix Condition 2'] = fix_conditions[1] if len(fix_conditions) > 1 else ''
    row['Fix Condition 3'] = fix_conditions[2] if len(fix_conditions) > 2 else ''
    row['Fix Component 1'] = fix_components[0] if len(fix_components) > 0 else ''
    row['Fix Component 2'] = fix_components[1] if len(fix_components) > 1 else ''
    row['Fix Component 3'] = fix_components[2] if len(fix_components) > 2 else ''

    return row


task_data = task_data.apply(tag_data, axis=1)

task_data
# Out:
#      Primary Key Order Date Product Category  \
# 0    SO0026296-1 2023-03-08           SPRAYS
# 1    SO0026385-1 2023-03-08           SPRAYS
# 2   SO0026385-11 2023-03-08           SPRAYS
# 3    SO0028352-1 2023-03-08           SPRAYS
# 4    SO0028770-1 2023-03-08           SPRAYS
# 5    SO0029596-1 2023-03-08           SPRAYS
# 6    SO0058466-2 2023-05-05           SPRAYS
# 7    SO0058466-3 2023-05-16           SPRAYS
# 8    SO0058466-4 2023-05-16           SPRAYS
# 9    SO0058466-5 2023-05-16           SPRAYS
# 10   SO0058668-1 2023-05-31           SPRAYS
# 11   SO0058674-1 2023-05-31           SPRAYS
# 12   SO0058674-2 2023-05-31           SPRAYS
# 13  SO0058727-15 2023-06-19           SPRAYS
# 14   SO0058727-2 2023-06-05           SPRAYS
# 15   SO0058727-5 2023-06-09           SPRAYS
# 16   SO0058727-6 2023-06-09           SPRAYS
# 17   SO0058796-1 2023-07-13           SPRAYS
# 18   SO0058796-4 2023-07-17            BALER
# 19   SO0058796-4 2023-07-17            BALER
#
#                                             Complaint  \
# 0   visibly notice fasteners under cab on p clips ...
# 1                        fuel door will not stay open
# 2      compressor pressure line braided steel crushed
# 3                  oil running from bottom of machine
# 4                       missing vector intrip unlocks
# 5   oil dripping from coupler of return line to pr...
# 6        components missing on boom to mount smv sign
# 7   oil dripping from bottom of machinepictures in...
# 8                                            oil leak
# 9                                       harness broke
# 10                                    rinse tank leak
# 11                                   fuel sender open
# 12                                     hydraulic leak
# 13                                     hydraulic leak
# 14                boom fold uneven and hitting cradle
# 15        customer is getting fault code f ¼à 354¼à31
# 16                                auto boom wont work
# 17                                    def error codes
# 18                 massive product leak under machine
# 19                                    condenser loose
#
#                                                 Cause  \
# 0                              not tighten at factory
# 1      gas strut not installed or anywhere on machine
# 2   compressor pressure line braided steel crushed...
# 3   oil return under machine swivel fitting left l...
# 4    missing vector intrip unlocks were not installed
# 5                                 coupler was leaking
# 6                           not included from factory
# 7   oring on male quick connect sticking out of fi...
# 8                                         blown oring
# 9                            poor material in harness
# 10                        sight glass tube is leaking
# 11        failed sending unitpn 51457614unit hrs 1975
# 12  no oring in bottom oil cooler fittingunit hrs ...
# 13  factory did not tighten hose part number 90391635
# 14                               sensors out of range
# 15  lubricant used on oring had drip down contamin...
# 16       faulty autoboom sensorautoboom node software
# 17                    internal issue in supply module
# 18            transducer was only screwed in a thread
# 19     faulty bolts in bracketpn 47953465unit hrs 265
#
#                                            Correction           Root Cause  \
# 0   go through and retighten all p clips nuts and ...          not tighten
# 1   found gas strut not installed or anywhere on m...        not installed
# 2   drain air from systemremove associated p clips...
# 3   oil return under machine swivel fitting left l...
# 4            installed missing unlocks ran and tested        not installed
# 5   remove coupler free up with hammer and socket ...              leaking
# 6   service call 7 milesinstall missing brackets a...         not included
# 7   service call14 milesoring on male quick connec...         not included
# 8   loaded truck and drove out to sprayer got to s...                blown
# 9   i was out to farm and i replaced the ncv harne...        poor material
# 10  total miles 160mileage in 181342mileage out 18...              leaking
# 11  began troubleshooting fuel sender code pulled ...       failed sending
# 12  began troubleshooting oil leak found it was dr...             no oring
# 13  service callstart machine to find leaking hose...          not tighten
# 14  kevin hammer of cnh was here to go over the pd...         out of range
# 15  remove intake humidity sensorlubricant used on...                fault
# 16  total miles 163mileage out 17263mileage in 174...                fault
# 17  i went out to field and i hooked up est and fo...       internal issue
# 18  found elbow fitting for pump transducer was on...  screwed in a thread
# 19  drove machine into shop found that the condens...                fault
#
#    Symptom Condition 1       Symptom Component 1 Symptom Condition 2  \
# 0                loose
# 1                 open                 fuel door      wont stay open
# 2              crushed  compressor pressure line             crushed
# 3          oil running                                         loose
# 4              missing                    vector             missing
# 5         oil dripping                   coupler                leak
# 6              missing                      boom
# 7         oil dripping
# 8             oil leak                                          leak
# 9                broke                   harness
# 10                leak                rinse tank                leak
# 11                open               fuel sender
# 12                leak                                hydraulic leak
# 13                leak                                hydraulic leak
# 14         fold uneven                      boom
# 15  getting fault code                    sensor
# 16                                          boom
# 17         error codes
# 18                leak                                  product leak
# 19               loose                 condenser
#
#    Symptom Component 2 Symptom Condition 3       Symptom Component 3  \
# 0
# 1
# 2        braided steel                      compressor pressure line
# 3
# 4       intrip unlocks                                        vector
# 5              coupler
# 6       mount svm sign
# 7
# 8                           hydraulic leak
# 9              harness
# 10
# 11
# 12                                oil leak
# 13                                oil leak
# 14              sensor
# 15
# 16           auto boom                                          boom
# 17
# 18
# 19
#
#    Fix Condition 1 Fix Component 1 Fix Condition 2     Fix Component 2  \
# 0      retightened           bolts                  bulkhead connector
# 1        installed       gas strut
# 2         replaced   braided steel                     compressor line
# 3         replaced           oring                           hydraulic
# 4        installed                         reseted
# 5         replaced         coupler
# 6                         brackets                               bolts
# 7                            oring                           hydraulic
# 8                            oring                               oring
# 9        installed     ncv harness        replaced             harness
# 10     cleaned out            tube
# 11                          vector                               oring
# 12       installed           oring       tightened               oring
# 13        replaced           oring       tightened               oring
# 14                          sensor
# 15                           oring                               oring
# 16                          sensor
# 17                         counter                             harness
# 18        replaced         threads                        pipe fitting
# 19                         threads                            brackets
#
#    Fix Condition 3 Fix Component 3
# 0                           vector
# 1
# 2
# 3                            oring
# 4
# 5
# 6                         svm sign
# 7                            oring
# 8                          coupler
# 9
# 10
# 11                           oring
# 12     retightened
# 13     retightened
# 14
# 15                          sensor
# 16
# 17
# 18                             elb
# 19

# %%
with pd.ExcelWriter(file_path, engine='openpyxl', mode='a') as writer:
    task_data.to_excel(writer, sheet_name='Tagged_data', index=False)
